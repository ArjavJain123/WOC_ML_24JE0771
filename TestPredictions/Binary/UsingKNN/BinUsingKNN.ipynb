# %% [markdown]
# # Dataset: BinaryClassification
# # Algorithm: KNN
#
# 1. Importing modules and datafiles

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# !pip install gdown
import gdown
#this way, anyone can access the files without mounting google driving. Accessing the csv files:
csvFileID = '1GZEf5NV8rX1xbqfaoOp0qrnhzyBQLZ0I'
url = f'https://drive.google.com/uc?id={csvFileID}'
csvOutputFile = 'mutli_classification_train.csv'
gdown.download(url, csvOutputFile, quiet=False)

#accessing the module files:
moduleFileID = '1GoMIkWx8lbzUdWbcY5utwC011Jr1A2qi'
url = f'https://drive.google.com/uc?id={moduleFileID}'
moduleOutputFile = 'KNN.py'
gdown.download(url, moduleOutputFile, quiet=False)
from KNN import KNN
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1GZEf5NV8rX1xbqfaoOp0qrnhzyBQLZ0I
# To: /content/mutli_classification_train.csv
# 100%|██████████| 18.6M/18.6M [00:00<00:00, 22.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1GoMIkWx8lbzUdWbcY5utwC011Jr1A2qi
# From (redirected): https://drive.google.com/uc?id=1GoMIkWx8lbzUdWbcY5utwC011Jr1A2qi&confirm=t&uuid=c09e88f7-eb1f-43ce-9d72-0f419b10085c
# To: /content/KNN.py
# 100%|██████████| 8.31k/8.31k [00:00<00:00, 16.1MB/s]

# %% [markdown]
# 2. Using Pandas to read the csv file

# %%
data = pd.read_csv(csvOutputFile)
data.head()
# Out:
#    ID  Feature_1   Feature_2   Feature_3   Feature_4   Feature_5   Feature_6  \
# 0   1 -36.963099  -15.014703   87.100435  101.523360   82.106571  -10.956180
# 1   2 -43.715674   18.847116   89.543406  -71.319314   35.597052  126.358570
# 2   3 -30.737550  -63.729643  106.081332   81.773948  112.769976  -12.425351
# 3   4 -27.674757 -118.869495  135.605213   99.130189   50.947548  -63.704785
# 4   5 -28.654141  -77.746597   85.215365   50.374774   79.763207  -32.703048
#
#    Feature_7  Feature_8   Feature_9  ...  Feature_12  Feature_13  Feature_14  \
# 0   0.592326 -51.919028  -90.650434  ...  -81.183744   13.101921   18.051450
# 1 -29.837495 -40.473764  -94.079238  ...  -37.848260    7.457352  -77.420742
# 2 -29.913286 -41.771200   16.424511  ... -106.610289    5.930143  -30.177083
# 3  -7.353057 -58.140229  -80.209027  ... -149.056417    3.893419  -74.100869
# 4 -28.152031 -63.994794 -153.566789  ... -102.731465   11.160205  -13.395073
#
# ...

# %%
feature_col = [f"Feature_{i}" for i in range(1,21)]
X = data[feature_col].to_numpy()
Y = data['Class'].to_numpy()
IDs = data['ID'].to_numpy()

# %% [markdown]
# 3. Standardizing X using z-score

# %%
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

# %% [markdown]
# 4. Importing the test dataset 'binary_classification_test.csv'

# %%
DataFileID = '19Wwiu1CMGuF4p26aDtlVQjb-8b0x3Lpa'
url = f'https://drive.google.com/uc?id={DataFileID}'
DataOutputFile = 'binary_classification_test.csv'
gdown.download(url, DataOutputFile, quiet=False)
df = pd.read_csv(DataOutputFile)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19Wwiu1CMGuF4p26aDtlVQjb-8b0x3Lpa
# To: /content/multi_classification_test.csv
# 100%|██████████| 4.61M/4.61M [00:00<00:00, 77.7MB/s]

# %%
print(df.head())
# Out:
#    ID  Feature_1   Feature_2   Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1 -21.263636 -101.510764   70.115563 -67.257828  60.603386 -14.047965
# 1   2 -28.646489 -104.090028  124.098974 -45.906780  85.691869  91.241763
# 2   3 -34.084427 -149.471464  131.883193  96.372918  41.865528 -14.692982
# 3   4 -38.905587 -126.038930   86.480118 -76.173919  98.722116  15.411935
# 4   5 -41.041415 -124.302646   89.549410 -98.980090  72.425692  15.907022
#
#    Feature_7  Feature_8   Feature_9  ...  Feature_11  Feature_12  Feature_13  \
# 0 -20.077225 -39.171738 -109.037261  ...    7.362312  -55.689290   11.794318
# 1  -2.532164 -43.701116 -151.491278  ...  -45.258211  -55.069378   11.297918
# 2  25.448955 -56.218421 -179.342647  ...  -29.196270  -34.475233    0.030514
# 3 -35.391915 -23.142612 -109.017318  ...  -49.361568 -103.689725   12.311099
# 4   5.400643 -32.267154 -181.961829  ...   -3.392246  -27.353560   13.073419
#
# ...

# %% [markdown]
# 5. Standardizing X_data

# %%
X_data = df[feature_col].to_numpy()
X_data = (X_data- X_mean) / X_std
print(X_data.shape)
# Out:
# (12000, 20)

# %% [markdown]
# 6. Initializing the model and then generating predictions array using the X_data array. Using k=11, which I found to be the optimal k value, using elbow method (in experimentation files)

# %%
model = KNN()
predictions = model.predict(X, Y, X_data, knn_k=11)

# %% [markdown]
# 7. Finally, storing the target class labels vs IDs into pandas DataFrame and then exporting it to csv file format

# %%
mappings = []
for i in range(X_data.shape[0]):
  mappings.append((i+1, predictions[i]))
OutDF = pd.DataFrame(mappings, columns=['ID', 'Class'])
OutDF.to_csv('output.csv', index=False)
